# %% [markdown]
# # Sesión 2.1. Análisis textual en Python
#
# En esta sesión se pretende trabajar con algunos de los conceptos básicos de Python para el procesamiento de texto dentro del Bloque II de la asignatura Deep Learning para el Procesamiento del Lenguaje Natural del Máster de IA de la Universidad de Murcia.

# %% [markdown]
# ## Apartado 1.0
#
# Descargamos primero el dataset "datasetEspañol.csv" con el que vamos a trabajar.

# %%
# !wget --no-check-certificate http://valencia.inf.um.es/dlpln/datasetEspañol.csv
# Out:
# --2024-10-28 15:14:26--  http://valencia.inf.um.es/dlpln/datasetEspa%C3%B1ol.csv
# Resolving valencia.inf.um.es (valencia.inf.um.es)... 155.54.204.133
# Connecting to valencia.inf.um.es (valencia.inf.um.es)|155.54.204.133|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1953117 (1.9M) [text/csv]
# Saving to: ‘datasetEspañol.csv’
#
# datasetEspañol.csv  100%[===================>]   1.86M  2.11MB/s    in 0.9s
#
# 2024-10-28 15:14:27 (2.11 MB/s) - ‘datasetEspañol.csv’ saved [1953117/1953117]

# %% [markdown]
# ## Apartado 1.1
# Para ello cargaremos primero el dataset en CSV proporcionado "datasetEspañol.csv" usando la librería **pandas**
#
# Mostraremos también las primeras líneas del CSV cargado

# %%
import pandas as pd
import csv

data = pd.read_csv('datasetEspañol.csv', encoding="UTF-8")
data.head()
# Out:
#             twitter_id   twitter_created_at  \
# 0  1262775925831340033  2020-05-19 20:03:36
# 1  1238776542270029824  2020-03-14 11:38:37
# 2  1238774281775067136  2020-03-14 11:29:38
# 3  1238811338484469763  2020-03-14 13:56:53
# 4  1238917460625166336  2020-03-14 20:58:35
#
#                                                tweet  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...
# 1  Muchos ánimos a todos los compañeros, profesio...
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...
# 3  #GabineteDeCrisisUtil #16 Escucha música! la q...
# 4  Increible el festival de musica gratuito que h...
#
#                                 corpus             user  agreement  votes  \
# 0  Estado de alarma nacional (oficial)         Lorenhia        100      3
# 1  Estado de alarma nacional (oficial)  VacunaJesusRuiz        100      2
# 2  Estado de alarma nacional (oficial)    jbautyoficial        100      2
# 3  Estado de alarma nacional (oficial)         ton1pons        100      2
# 4  Estado de alarma nacional (oficial)        Alexiat84        100      2
#
#    score     label __split
# 0      3  positive     val
# 1      2  positive   train
# 2      2  positive   train
# 3      2  positive   train
# 4      2  positive   train

# %% [markdown]
# ## Apartado 1.2
#
# Seleccionamos únicamente las 200 primeras filas y las columnas 'twitter_id', 'tweet', 'user' y 'label' y guardamos de nuevo el CSV en el fichero "datasetEspañolReducido.csv".
#
# A partir de ahora trabajaremos con este dataset reducido.

# %%
data2 = data[0:200][['twitter_id', 'tweet', 'user', 'label']]
data2.to_csv('datasetReducido.csv', encoding="UTF-8", index=False, quoting=csv.QUOTE_ALL)

data2.head()
# Out:
#             twitter_id                                              tweet  \
# 0  1262775925831340033  Hoy merendola deliciosa! Latte Macchiato Caram...
# 1  1238776542270029824  Muchos ánimos a todos los compañeros, profesio...
# 2  1238774281775067136  Hay TANTAS cosas que se pueden hacer en casa: ...
# 3  1238811338484469763  #GabineteDeCrisisUtil #16 Escucha música! la q...
# 4  1238917460625166336  Increible el festival de musica gratuito que h...
#
#               user     label
# 0         Lorenhia  positive
# 1  VacunaJesusRuiz  positive
# 2    jbautyoficial  positive
# 3         ton1pons  positive
# 4        Alexiat84  positive

# %% [markdown]
# ## Apartado 1.3
#
# Ahora trabajaremos detectando de manera sencilla algunas expresiones regulares usando la librería **re**.
#
# Para ello seleccionaremos los **hashtags** y **menciones** de los tuits.
#
# Una expresión regular para detectar los hashtags podría ser la siguiente:
# \#[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9\_\-]+
#
# Además, crearemos una nueva columna 'tweet_clean' que no contenga los hashtags ni menciones.
#
# - Usaremos la función "apply" y "lambda" de Pandas.
# - Para detectar si la expresión regular existe en un determinado String usaremos la función re.sub()

# %%
import re

hashtagregex = '#[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9_-]+'
mentionregex = '@[A-Za-záéíóúÁÉÍÓÚÜüÑñ0-9_-]+'

data2['tweet_clean'] = data2['tweet'].apply(lambda x: re.sub(hashtagregex,"",x))
data2['tweet_clean'] = data2['tweet_clean'].apply(lambda x: re.sub(mentionregex,"",x))
data2.tail()
# Out:
#               twitter_id                                              tweet  \
# 195  1238778301855997952  Bueno...pues ya está!... Ya tengo ordenados lo...
# 196  1238778084129718273  Han cerrado el corte ingles y ya no tengo que ...
# 197  1238778027217170432  Juventud de España!!! Quedaos en casa. #YoMeQu...
# 198  1238777781728751617  Saludos desde @CADENA100 aquí también estamos ...
# 199  1238777648815505412  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...
#
#                 user     label  \
# 195    Tuitero_David  positive
# 196   AinhoaDelPilar  positive
# 197         XulesRun  positive
# 198  NavarroAlmudena  positive
# 199   Anakin73630326  positive
#
#                                            tweet_clean
# 195  Bueno...pues ya está!... Ya tengo ordenados lo...
# 196  Han cerrado el corte ingles y ya no tengo que ...
# 197      Juventud de España!!! Quedaos en casa. . . .
# 198  Saludos desde  aquí también estamos cumpliendo...
# 199  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...

# %% [markdown]
# ## Apartado 1.4
#
# Una vez detectadas las expresiones regulares, procederemos a crear dos nuevas columnas con los **hashtags** y **menciones** respectivamente.
#
# - Podemos usar la función re.findall()

# %%
data2['hashtags'] = data2['tweet'].apply(lambda x: re.findall(hashtagregex,x))
data2['mentions'] = data2['tweet'].apply(lambda x: re.findall(mentionregex,x))

data2.head()
# Out:
#             twitter_id                                              tweet  \
# 0  1262775925831340033  Hoy merendola deliciosa! Latte Macchiato Caram...
# 1  1238776542270029824  Muchos ánimos a todos los compañeros, profesio...
# 2  1238774281775067136  Hay TANTAS cosas que se pueden hacer en casa: ...
# 3  1238811338484469763  #GabineteDeCrisisUtil #16 Escucha música! la q...
# 4  1238917460625166336  Increible el festival de musica gratuito que h...
#
#               user     label  \
# 0         Lorenhia  positive
# 1  VacunaJesusRuiz  positive
# 2    jbautyoficial  positive
# 3         ton1pons  positive
# 4        Alexiat84  positive
#
#                                          tweet_clean  \
# 0  Hoy merendola deliciosa! Latte Macchiato Caram...
# 1  Muchos ánimos a todos los compañeros, profesio...
# 2  Hay TANTAS cosas que se pueden hacer en casa: ...
# 3    Escucha música! la que te gusta, pero tambié...
# 4  Increible el festival de musica gratuito que h...
#
#                                             hashtags       mentions
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]

# %% [markdown]
# ## Apartado 1.5
#
# Sobre esa nueva columna 'tweet_clean' quitaremos los símbolos de puntuación haciendo uso de la librería **string**
#
# Podemos usar la siguiente función
#
# ```
# #defining the function to remove punctuation
# import string
#
# spanish_punctuation = string.punctuation+'¿'+'¡'
# def remove_punctuation(text):
#     punctuationfree="".join([i if i not in spanish_punctuation else " " for i in text])
#     return punctuationfree
#
# ```

# %%
import string

spanish_punctuation = string.punctuation+'¿'+'¡'

def remove_punctuation(text):
    punctuationfree="".join([i if i not in spanish_punctuation else " " for i in text])
    return punctuationfree

data2['tweet_clean'] = data2['tweet_clean'].apply(lambda x: remove_punctuation(x))
data2.tail()
# Out:
#               twitter_id                                              tweet  \
# 195  1238778301855997952  Bueno...pues ya está!... Ya tengo ordenados lo...
# 196  1238778084129718273  Han cerrado el corte ingles y ya no tengo que ...
# 197  1238778027217170432  Juventud de España!!! Quedaos en casa. #YoMeQu...
# 198  1238777781728751617  Saludos desde @CADENA100 aquí también estamos ...
# 199  1238777648815505412  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...
#
#                 user     label  \
# 195    Tuitero_David  positive
# 196   AinhoaDelPilar  positive
# 197         XulesRun  positive
# 198  NavarroAlmudena  positive
# 199   Anakin73630326  positive
#
#                                            tweet_clean  \
# 195  bueno   pues ya está     ya tengo ordenados lo...
# 196  han cerrado el corte ingles y ya no tengo que ...
# 197              juventud de españa    quedaos en casa
# 198  saludos desde  aquí también estamos cumpliendo...
# 199  homenaje a todos los sanitarios   a las diez h...
#
#                                               hashtags      mentions
# 195                                 [#YoMeQuedoEnCasa]            []
# 196                    [#YoMeQuedoEnCasa, #cuarentena]            []
# 197  [#YoMeQuedoEnCasa, #coranavirus, #coronavirusE...   [@spiriman]
# 198  [#SeviciosMíminos, #OnAir, #teletrabajo, #YoMe...  [@CADENA100]
# 199                                 [#YoMeQuedoEnCasa]            []

# %% [markdown]
# ## Apartado 1.6
#
# Cambiamos el texto de la columna 'tweet_clean' y lo podemos todo en *lowercase*.
#
# Para eso utilizamos la función lower() del objeto string

# %%
data2['tweet_clean'] = data2['tweet_clean'].apply(lambda x: x.lower().strip())
data2.head()
# Out:
#             twitter_id                                              tweet  \
# 0  1262775925831340033  Hoy merendola deliciosa! Latte Macchiato Caram...
# 1  1238776542270029824  Muchos ánimos a todos los compañeros, profesio...
# 2  1238774281775067136  Hay TANTAS cosas que se pueden hacer en casa: ...
# 3  1238811338484469763  #GabineteDeCrisisUtil #16 Escucha música! la q...
# 4  1238917460625166336  Increible el festival de musica gratuito que h...
#
#               user     label  \
# 0         Lorenhia  positive
# 1  VacunaJesusRuiz  positive
# 2    jbautyoficial  positive
# 3         ton1pons  positive
# 4        Alexiat84  positive
#
#                                          tweet_clean  \
# 0  hoy merendola deliciosa  latte macchiato caram...
# 1  muchos ánimos a todos los compañeros  profesio...
# 2  hay tantas cosas que se pueden hacer en casa  ...
# 3  escucha música  la que te gusta  pero también ...
# 4  increible el festival de musica gratuito que h...
#
#                                             hashtags       mentions
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]

# %% [markdown]
# ## Apartado 1.7
#
# Aplicamos un tokenizer sencillo y guardamos todos los tokens de los tuits limpios en otra columna 'tweet_clean_tokens' usando la siguiente función sencilla de Tokenizer.
#
# ```
# #defining function for tokenization
# import re
# def tokenization(text):
#     tokens = re.split('\W+',text)
#     return tokens
# ```

# %%
# defining function for tokenization
import re
def tokenization(text):
    tokens = re.split('\W+',text)
    return tokens

data2['tweet_clean_tokens'] = data2['tweet_clean'].apply(lambda x: tokenization(x))
data2.head()
# Out:
#             twitter_id                                              tweet  \
# 0  1262775925831340033  Hoy merendola deliciosa! Latte Macchiato Caram...
# 1  1238776542270029824  Muchos ánimos a todos los compañeros, profesio...
# 2  1238774281775067136  Hay TANTAS cosas que se pueden hacer en casa: ...
# 3  1238811338484469763  #GabineteDeCrisisUtil #16 Escucha música! la q...
# 4  1238917460625166336  Increible el festival de musica gratuito que h...
#
#               user     label  \
# 0         Lorenhia  positive
# 1  VacunaJesusRuiz  positive
# 2    jbautyoficial  positive
# 3         ton1pons  positive
# 4        Alexiat84  positive
#
#                                          tweet_clean  \
# 0  hoy merendola deliciosa  latte macchiato caram...
# 1  muchos ánimos a todos los compañeros  profesio...
# 2  hay tantas cosas que se pueden hacer en casa  ...
# 3  escucha música  la que te gusta  pero también ...
# 4  increible el festival de musica gratuito que h...
#
#                                             hashtags       mentions  \
# 0  [#yomequedoencasa, #todovaasalirbien, #undiame...             []
# 1      [#CoronavirusESP, #YoMeQuedoEnCasa, #vacunas]             []
# 2               [#YoMeQuedoEnCasa, #quedateEnTuCasa]             []
# 3  [#GabineteDeCrisisUtil, #16, #YoMeQuedoEnCasa,...             []
# 4                                 [#YoMeQuedoEnCasa]  [@NilMoliner]
#
#                                   tweet_clean_tokens
# 0  [hoy, merendola, deliciosa, latte, macchiato, ...
# 1  [muchos, ánimos, a, todos, los, compañeros, pr...
# 2  [hay, tantas, cosas, que, se, pueden, hacer, e...
# 3  [escucha, música, la, que, te, gusta, pero, ta...
# 4  [increible, el, festival, de, musica, gratuito...

# %% [markdown]
# ## Apartado 1.8
#
# **NLTK** es una librería con distintas herramientas para el PLN. La vamos a utilizar para descargar las stopwords en español y para usar su stemmer.
#
# El siguiente paso sería eliminar las stopwords de los tokens usando la librería **NLTK**. Ver función siguiente.
#
#
#
# ```
# import nltk
# #Stop words present in the library
# nltk.download('stopwords')
# stopwords = nltk.corpus.stopwords.words('spanish')
#
#
# #defining the function to remove stopwords from tokenized text
# def remove_stopwords(text):
#     output= [i for i in text if i not in stopwords]
#     return output
#
# ```

# %%
import nltk
# Stop words present in the library
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('spanish')


# defining the function to remove stopwords from tokenized text
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output

data2['tweet_clean_tokens'] = data2['tweet_clean_tokens'].apply(lambda x: remove_stopwords(x))
data2.tail()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#               twitter_id                                              tweet  \
# 195  1238778301855997952  Bueno...pues ya está!... Ya tengo ordenados lo...
# 196  1238778084129718273  Han cerrado el corte ingles y ya no tengo que ...
# 197  1238778027217170432  Juventud de España!!! Quedaos en casa. #YoMeQu...
# 198  1238777781728751617  Saludos desde @CADENA100 aquí también estamos ...
# 199  1238777648815505412  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...
#
#                 user     label  \
# 195    Tuitero_David  positive
# 196   AinhoaDelPilar  positive
# 197         XulesRun  positive
# 198  NavarroAlmudena  positive
# 199   Anakin73630326  positive
#
#                                            tweet_clean  \
# 195  bueno   pues ya está     ya tengo ordenados lo...
# 196  han cerrado el corte ingles y ya no tengo que ...
# 197              juventud de españa    quedaos en casa
# 198  saludos desde  aquí también estamos cumpliendo...
# 199  homenaje a todos los sanitarios   a las diez h...
#
#                                               hashtags      mentions  \
# 195                                 [#YoMeQuedoEnCasa]            []
# 196                    [#YoMeQuedoEnCasa, #cuarentena]            []
# 197  [#YoMeQuedoEnCasa, #coranavirus, #coronavirusE...   [@spiriman]
# 198  [#SeviciosMíminos, #OnAir, #teletrabajo, #YoMe...  [@CADENA100]
# 199                                 [#YoMeQuedoEnCasa]            []
#
#                                     tweet_clean_tokens
# 195  [bueno, pues, ordenados, condones, fecha, cadu...
# 196  [cerrado, corte, ingles, ir, trabajar, sincera...
# 197                  [juventud, españa, quedaos, casa]
# 198  [saludos, aquí, cumpliendo, resto, tiempo, así...
# 199  [homenaje, sanitarios, diez, horas, noche, sal...

# %% [markdown]
# ## Apartado 1.9
#
# Por último usando el SnowballStemmer de NLTK obtenemos los stems de cada una de los tokens sin las stopwords y lo guardamos en otra columna 'tweet_clean_stemmed_tokens'
#
#
#
# ```
# from nltk.stem import SnowballStemmer
# stemmer = SnowballStemmer('spanish')
#
# #defining a function for stemming
# def stemming(text):
#   stem_text = [stemmer.stem(word) for word in text]
#   return stem_text
#   ```

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')

# defining a function for stemming
def stemming(text):
    stem_text = [stemmer.stem(word) for word in text]
    return stem_text

data2['tweet_cleaned_stemmed_tokens'] = data2['tweet_clean_tokens'].apply(lambda x: stemming(x))
data2.tail()
# Out:
#               twitter_id                                              tweet  \
# 195  1238778301855997952  Bueno...pues ya está!... Ya tengo ordenados lo...
# 196  1238778084129718273  Han cerrado el corte ingles y ya no tengo que ...
# 197  1238778027217170432  Juventud de España!!! Quedaos en casa. #YoMeQu...
# 198  1238777781728751617  Saludos desde @CADENA100 aquí también estamos ...
# 199  1238777648815505412  HOMENAJE A TODOS LOS SANITARIOS ??A LAS DIEZ H...
#
#                 user     label  \
# 195    Tuitero_David  positive
# 196   AinhoaDelPilar  positive
# 197         XulesRun  positive
# 198  NavarroAlmudena  positive
# 199   Anakin73630326  positive
#
#                                            tweet_clean  \
# 195  bueno   pues ya está     ya tengo ordenados lo...
# 196  han cerrado el corte ingles y ya no tengo que ...
# 197              juventud de españa    quedaos en casa
# 198  saludos desde  aquí también estamos cumpliendo...
# 199  homenaje a todos los sanitarios   a las diez h...
#
#                                               hashtags      mentions  \
# 195                                 [#YoMeQuedoEnCasa]            []
# 196                    [#YoMeQuedoEnCasa, #cuarentena]            []
# 197  [#YoMeQuedoEnCasa, #coranavirus, #coronavirusE...   [@spiriman]
# 198  [#SeviciosMíminos, #OnAir, #teletrabajo, #YoMe...  [@CADENA100]
# 199                                 [#YoMeQuedoEnCasa]            []
#
#                                     tweet_clean_tokens  \
# 195  [bueno, pues, ordenados, condones, fecha, cadu...
# 196  [cerrado, corte, ingles, ir, trabajar, sincera...
# 197                  [juventud, españa, quedaos, casa]
# 198  [saludos, aquí, cumpliendo, resto, tiempo, así...
# 199  [homenaje, sanitarios, diez, horas, noche, sal...
#
#                           tweet_cleaned_stemmed_tokens
# 195  [buen, pues, orden, condon, fech, caduc, cos, ...
# 196  [cerr, cort, ingles, ir, trabaj, sincer, alivi...
# 197                      [juventud, españ, queda, cas]
# 198  [salud, aqu, cumpl, rest, tiemp, asi, cuant, s...
# 199  [homenaj, sanitari, diez, hor, noch, saldr, ve...

# %% [markdown]
# ##Apartado 1.10  Simple corrección ortográfica (Resuelto)
# Muchos textos tienen errores léxicos y hay distintas librerías para la corrección ortográfica a partir de diccionarios. Una de ellas es la librería **pyspellchecker**
#
# Hay otras opciones como hunspell y pyenchant que hacen una corrección léxica basada en diccionarios

# %%
# instalamos la librería
# !pip3 install pyspellchecker

#importamos la librería
import spellchecker

texto_erróneo = "La asginatura del master haze trabajar y aprehnder procesamiengo de teexto"

# Crea un objeto SpellChecker para el idioma especificado
spell = spellchecker.SpellChecker(language='es')

# Divide el texto en palabras
palabras = texto_erróneo.split()

# Inicializa una lista para las palabras corregidas
palabras_corregidas = []

# Verifica cada palabra en el texto
for palabra in palabras:
# Si la palabra está mal escrita, sugiere correcciones
   correccion = spell.correction(palabra)
   palabras_corregidas.append(correccion)

# Unimos las palabras corregidas para formar el texto corregido
texto_corregido = ' '.join(palabras_corregidas)
print(texto_corregido)
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.8.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pyspellchecker-0.8.1-py3-none-any.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 37.3 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.8.1
# La asignatura del aster haz trabajar y aprender procesamiento de texto

# %% [markdown]
# ## Ejercicio a resolver en casa
# Una vez visto el framework stanza en el siguiente Notebook P1.2, crear una columna 'tweet_entities' con las entidades del texto.
#
# Una mejora de este ejercicio es crear una columna para cada tipo de entidad detectada.
#
# Debido a que puede tardar bastante tiempo, podéis hacerlo con un subconjunto del dataset de unas 20 líneas.
